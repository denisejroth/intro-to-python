# %% [markdown]
# <a href="https://colab.research.google.com/github/denisejroth/intro-to-python/blob/main/1_getting_started/notebooks/getting_started_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python
# ## Module 1 — Getting Started  ·  **SOLUTIONS**
#
# ---
#
# This notebook is where you *do* Python. Read each explanation, run each code cell (`Shift +
# Enter`), and try the **✏️ Exercises**. Every exercise here is filled in with one possible answer.

# %% [markdown]
# ## 1. `print()` — your window into the code
#
# `print()` displays whatever you give it. Run this:

# %%
print("Hello, world!")

# %% [markdown]
# You can print multiple things by separating them with commas:

# %%
print("The answer is", 42)

# %% [markdown]
# ## 2. Variables
#
# A **variable** stores a value under a name, using `=`.

# %%
name = "Denise"
age = 35

print(name)
print(age)

# %% [markdown]
# Variables can be updated, and used in calculations:

# %%
age = age + 1     # add one to whatever age currently is
print(age)

# %% [markdown]
# > **✏️ Exercise 1**
# >
# > Create a variable `city` holding the name of your city, and a variable `population` holding a
# > number. Print both.

# %%
# ✅ Solution
city = "Wageningen"
population = 40000
print(city)
print(population)

# %% [markdown]
# ## 3. Data types
#
# Every value has a **type**. Check it with `type()`.

# %%
print(type(42))        # int  — whole number
print(type(3.14))      # float — decimal
print(type("hello"))   # str  — text
print(type(True))      # bool — True/False

# %% [markdown]
# > **✏️ Exercise 2**
# >
# > Make one variable of each type (an int, a float, a string, and a bool) and print the type of
# > each.

# %%
# ✅ Solution
count = 10          # int
price = 4.99        # float
label = "policy"    # str
is_valid = False    # bool

print(type(count))
print(type(price))
print(type(label))
print(type(is_valid))

# %% [markdown]
# ## 4. Arithmetic
#
# Python is a calculator. Note the less obvious operators: `//` (floor division), `%`
# (remainder), `**` (power).

# %%
print(7 + 3)    # 10
print(7 / 3)    # 2.333...  (division always gives a float)
print(7 // 3)   # 2         (floor division: drops the decimal)
print(7 % 3)    # 1         (remainder / modulo)
print(7 ** 3)   # 343       (7 to the power of 3)

# %% [markdown]
# > **✏️ Exercise 3**
# >
# > A meeting has 25 people and tables seat 4. Use `//` to compute how many tables are *fully*
# > filled, and `%` to compute how many people are left over.

# %%
# ✅ Solution
people = 25
per_table = 4

full_tables = people // per_table   # 6
leftover = people % per_table       # 1
print("Full tables:", full_tables)
print("Left over:", leftover)

# Comment: // and % are a classic pair — one gives the "how many whole groups",
# the other gives "what's left". Together they fully describe the division.

# %% [markdown]
# ## 5. Strings and f-strings
#
# Combine strings with `+`, or — much better — insert variables using **f-strings** (note the `f`
# before the opening quote, and the `{}` around variables).

# %%
first = "computational"
second = "text analysis"

# joining with +
print(first + " " + second)

# f-string: cleaner, and works with any type
field = "computational text analysis"
years = 3
print(f"I have studied {field} for {years} years.")

# %% [markdown]
# > **✏️ Exercise 4**
# >
# > Using an f-string, print a sentence that includes your `city` and `population` variables from
# > Exercise 1, like: `"Wageningen has about 40000 residents."`

# %%
# ✅ Solution
print(f"{city} has about {population} residents.")

# Comment: f-strings automatically convert numbers to text for you — no need to
# wrap `population` in str(). That's a big part of why they're so convenient.

# %% [markdown]
# ## 6. Converting between types
#
# Change a value's type with `int()`, `float()`, `str()`. This matters because you **can't mix
# types** carelessly.

# %%
# "5" is text, not a number — converting lets us do math
text_number = "5"
print(int(text_number) + 3)   # 8

# going the other way
print(str(42) + " apples")    # "42 apples"

# %% [markdown]
# **A common beginner error** — try running this cell and read the error message, then fix
# it in the exercise below:

# %%
# This will cause an error! (can't add text to a number)
# Uncomment to see the error:
# print("5" + 3)
print("Uncomment the line above to see a classic type error.")

# %% [markdown]
# > **✏️ Exercise 5**
# >
# > The line `"5" + 3` fails. Fix it two different ways: once so the result is the **number 8**,
# > and once so the result is the **text "53"**.

# %%
# ✅ Solution
# Way 1: convert the string to an int -> numeric addition
print(int("5") + 3)      # 8

# Way 2: convert the int to a string -> text joining
print("5" + str(3))      # "53"

# Comment: this shows why type matters — the SAME "+" symbol means "add" for numbers
# but "join" for strings. Python needs both sides to be the same type to know which you mean.

# %% [markdown]
# ## Wrap-up
#
# You can now:
# - Display output with `print()`
# - Store values in **variables**
# - Recognize the four core **types** (int, float, str, bool)
# - Do **arithmetic**, including `//`, `%`, `**`
# - Build text with **f-strings** and **convert** between types
#
# **Next:** Module 2 — **data structures** (lists and dictionaries), where we start holding
# *collections* of values.
